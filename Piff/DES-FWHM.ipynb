# %%
# %matplotlib notebook

import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import pickle

# %%
# read in csv file of CTIO DB
ctiodb = pd.read_csv("/u/ec/roodman/kipacdisk/CtioDB/db20120914to20160510.csv")
# Out:
# /nfs/slac/g/ki/ki06/roodman/Software/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,9,131,132,133,213,214) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
f,ax = plt.subplots(1,2)
axf = ax.flatten()

h = axf[0].scatter(ctiodb.expid,ctiodb.fwhm,s=0.05)
h = axf[1].hist(ctiodb.fwhm,bins=100,range=(0.,2.5))
# Out:
# <img src="data:image/png;base64,..." width="640">
# /nfs/slac/g/ki/ki06/roodman/Software/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /nfs/slac/g/ki/ki06/roodman/Software/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
dfout = ctiodb[['expid','fwhm','qc_fwhm']]
ok = dfout.fwhm>0.0
dfout = dfout[ok]

# %%
dfout.to_pickle('des_fwhm.pkl')
