# %%
# %matplotlib notebook
import numpy as np
from astropy.io import fits
from matplotlib import pyplot as plt
from matplotlib.ticker import MaxNLocator

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %%
hdu  = fits.open('shape_mode_meanify.fits')
xy = hdu[1].data['COORDS0'][0]
size = hdu[1].data['PARAMS0'][0][:,0]
g1 = hdu[1].data['PARAMS0'][0][:,1]
g2 = hdu[1].data['PARAMS0'][0][:,2]

# %%
x = xy[:,0]
y = xy[:,1]
print(x.shape)
# Out:
# (42515,)

# %%
f,ax = plt.subplots(1,1,figsize=(15,12))

xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()

hb = ax.hexbin(x, y, C=size, gridsize=150, cmap=plt.cm.RdBu,vmax=0.04, vmin=-0.04)
ax.axis([xmin, xmax, ymin, ymax])
ax.set_title("atmo_size")
cb = f.colorbar(hb, ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
f,ax = plt.subplots(1,1)
h = ax.hist(size,bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print(x)
# Out:
# [-1609.17178505 -1578.99153367 -1548.81128228 ...  1559.75461065
#   1589.93486204  1620.11511343]
